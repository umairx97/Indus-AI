# %% [markdown]
# # Chapter 9 If Statements

# %%
cat = 1
if cat == 1:
    print("So far so good.")
    print("Congratulations.")
    print("All done")
# Out:
# So far so good.
# Congratulations.
# All done

# %%
cat = 1
if cat == 1:
    print("So far so good.")
    print("Congratulations.")
    print("All done")
# Out:
# So far so good.
# Congratulations.
# All done
