# %% [markdown]
# # Chapter 12 Testing Set of conditions

# %%
weight = 200
time = 7
if weight > 300 and time < 6:
    status = "try to recruit him"
else:
    status = "Don't try to recruit him"
print (status)
# Out:
# Don't try to recruit him
