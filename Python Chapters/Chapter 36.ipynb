# %% [markdown]
# # Chapter 36 How to append a new dictionary to a list of dictionaries

# %%
Listofnums = [1, 2, 3, 4, 5, 6,7,8]
x = len(Listofnums)
print(x)
# Out:
# 8

# %%
customers = [
  {
    "customer id": 0,
    "first name":"Umair",
    "last name": "Ahmed",
  },
]
new_customer_id = len(customers)
new_first_name = "Asad"
new_last_name = "Addy"
new_dictionary = {
  "customer id": new_customer_id,
  "first name": new_first_name,
  "last name:": new_last_name,
}
customers.append(new_dictionary)
print(customers)
# Out:
# [{'customer id': 0, 'first name': 'Umair', 'last name': 'Ahmed'}, {'customer id': 1, 'first name': 'Asad', 'last name:': 'Addy'}]
