# %% [markdown]
# # Chapter 29 Dictionary: Adding Items

# %%
Student = {'name':'Umair', 'age': 21}

Student
#Output: 
print(Student)

# add item
Student['Location'] = 'Karachi'  

# Output: 
print(Student)
# Out:
# {'name': 'Umair', 'age': 21}
# {'name': 'Umair', 'age': 21, 'Location': 'Karachi'}

# %%
Student
# Out:
# {'name': 'Umair', 'age': 21, 'Location': 'Karachi'}
