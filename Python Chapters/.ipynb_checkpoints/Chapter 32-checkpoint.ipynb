# %% [markdown]
# # Chapter 32 Dictionaries: Looping through keys

# %%
Student = {'name': 'Umair', 'age': 21, 'salary': 43500.0}
Student.keys()
# Out:
# dict_keys(['name', 'age', 'salary'])

# %%
for k in Student.keys():
    print(k)
# Out:
# name
# age
# salary
