# %% [markdown]
# # Chapter 13 If nested statements

# %%
a = 10
b = 20 
c = 10
d = 20
x = 20
y = 10
f = 10
g = 10
h = 10
if c == d:
    if x == y:
        g = h
    elif a == b:
        g = h
    else:
        e = f
else:
    e = f
    
print (a)
print (b)
print (c)
print (d)
print (e)
print (f)
# Out:
# 10
# 20
# 10
# 20
# 10
# 10
