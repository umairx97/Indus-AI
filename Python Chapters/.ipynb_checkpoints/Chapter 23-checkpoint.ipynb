# %% [markdown]
# # Chapter 23 Getting Input From user and converting strings and numbers

# %%
print('Enter your name:');
#Getting input from user
x = input();
print ('Enter you Age');
a = input();
print('Hello, ' + x +' Your age is: ' + a);


#Converting Integer into string
print("Hello, " + str(x) + " Your age is: " + str(a));
# Out:
# Enter your name:
# Umair Ahmed
# Enter you Age
# 21
# Hello, Umair Ahmed  Your age is: 21
# Hello, Umair Ahmed  Your age is: 21
