# %% [markdown]
# # Chapter 61 Classes: Changing an attribute's value

# %%
class Student: 
	def __init__(self): 
		self.name = 'Umair Ahmed Bajwa'
		self.fees = 43000

	def show(self): 
		print (self.name)
		print (self.fees)

e1 = Student() 
print ("Information:", vars(e1))
# Out:
# Information: {'name': 'Umair Ahmed Bajwa', 'fees': 43000}
