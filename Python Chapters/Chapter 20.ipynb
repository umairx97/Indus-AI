# %% [markdown]
# # Chapter 20 Tuples

# %%
#Defining a Tuple 
Tuple1 = ("Karachi", "Lahore", "Islamabad", "Faislabad"); 
print (Tuple1);

#Print using for loop
for a in Tuple1: 
    print("City Name:" + a);
# Out:
# ('Karachi', 'Lahore', 'Islamabad', 'Faislabad')
# City Name:Karachi
# City Name:Lahore
# City Name:Islamabad
# City Name:Faislabad
