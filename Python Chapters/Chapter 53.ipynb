# %% [markdown]
# # Chapter 53 Classes

# %%
class Person:
    
    def __init__(self, name, age):
        self.name = name
        self.age = age

p1 = Person("Umair Ahmed", 21)

print(p1.name)
print(p1.age)
# Out:
# Umair Ahmed
# 21
