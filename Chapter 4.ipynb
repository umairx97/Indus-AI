# %% [markdown]
# # Chapter 4 Familiar Operators

# %%
num = .075total = num + 200
# Out:
#   File "<ipython-input-1-e3d12fd2313c>", line 1
#     num = .075total = num + 200
#                   ^
# SyntaxError: invalid syntax

# %%
num = .075
total = num + 200 

print(total)
# Out:
# 200.075
