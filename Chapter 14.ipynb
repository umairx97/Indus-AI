# %% [markdown]
# # Chapter 14 Comments

# %%
# This is a comment.
# This is another comment.
# Python ignores these comments.
# The code that Python executes is next, on line 5.
print("Hello, world!")
# Out:
# Hello, world!
