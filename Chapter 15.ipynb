# %% [markdown]
# # Chapter 15 Lists

# %%
city_0 = "Atlanta"
city_1 = "Baltimore"
city_2 = "Chicago"
city_3 = "Karachi"
city_4 = "Los Angeles"
city_5 = "Seattle"

print("Welcome to " + city_3)
# Out:
# Welcome to Karachi
